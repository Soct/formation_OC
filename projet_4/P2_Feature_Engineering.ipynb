# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)


df_merge = pd.read_csv("processed/data_merge.csv", index_col=0)

# %%
df_merge["genre"] = df_merge["genre"].map({'F': 0, 'M': 1})
df_merge["ayant_enfants"] = df_merge["ayant_enfants"].map({'Y': 0, 'N': 1})
df_merge["heure_supplementaires"] = df_merge["heure_supplementaires"].map({'Oui': 0, 'Non': 1})
df_merge["a_quitte_l_entreprise"] = df_merge["a_quitte_l_entreprise"].map({'Oui': 1, 'Non': 0})
df_merge = df_merge.drop("nombre_heures_travailless", axis=1)
df_merge.head()
# Out:
#    id_employee  age  genre  revenu_mensuel statut_marital departement  \
# 0            1   41      0            5993    Célibataire  Commercial
# 1            2   49      1            5130       Marié(e)  Consulting
# 2            4   37      1            2090    Célibataire  Consulting
# 3            5   33      0            2909       Marié(e)  Consulting
# 4            7   27      1            3468       Marié(e)  Consulting
#
#                     poste  nombre_experiences_precedentes  \
# 0        Cadre Commercial                               8
# 1  Assistant de Direction                               1
# 2              Consultant                               6
# 3  Assistant de Direction                               1
# 4              Consultant                               9
#
#    annee_experience_totale  annees_dans_l_entreprise  \
# 0                        8                         6
# 1                       10                        10
# 2                        7                         0
# 3                        8                         8
# 4                        6                         2
#
#    annees_dans_le_poste_actuel  satisfaction_employee_environnement  \
# 0                            4                                    2
# 1                            7                                    3
# 2                            0                                    4
# 3                            7                                    4
# 4                            2                                    1
#
#    note_evaluation_precedente  niveau_hierarchique_poste  \
# 0                           3                          2
# 1                           2                          2
# 2                           2                          1
# 3                           3                          1
# 4                           3                          1
#
#    satisfaction_employee_nature_travail  satisfaction_employee_equipe  \
# 0                                     4                             1
# 1                                     2                             4
# 2                                     3                             2
# 3                                     3                             3
# 4                                     2                             4
#
#    satisfaction_employee_equilibre_pro_perso  note_evaluation_actuelle  \
# 0                                          1                         3
# 1                                          3                         4
# 2                                          3                         3
# 3                                          3                         3
# 4                                          3                         3
#
#    heure_supplementaires augementation_salaire_precedente  \
# 0                      0                             11 %
# 1                      1                             23 %
# 2                      0                             15 %
# 3                      0                             11 %
# 4                      1                             12 %
#
#    a_quitte_l_entreprise  nombre_participation_pee  nb_formations_suivies  \
# 0                      1                         0                      0
# 1                      0                         1                      3
# 2                      1                         0                      3
# 3                      0                         0                      3
# 4                      0                         1                      3
#
#    nombre_employee_sous_responsabilite  distance_domicile_travail  \
# 0                                    1                          1
# 1                                    1                          8
# 2                                    1                          2
# 3                                    1                          3
# 4                                    1                          2
#
#    niveau_education            domaine_etude  ayant_enfants  \
# 0                 2            Infra & Cloud              0
# 1                 1            Infra & Cloud              0
# 2                 2                    Autre              0
# 3                 4            Infra & Cloud              0
# 4                 1  Transformation Digitale              0
#
#   frequence_deplacement  annees_depuis_la_derniere_promotion  \
# 0           Occasionnel                                    0
# 1              Frequent                                    1
# 2           Occasionnel                                    0
# 3              Frequent                                    3
# 4           Occasionnel                                    2
#
#    annes_sous_responsable_actuel
# 0                              5
# 1                              7
# 2                              0
# 3                              0
# 4                              2

# %%
df_merge["id_employee"] = df_merge["id_employee"].astype(int)

# %%
df_merge['augementation_salaire_precedente'] = df_merge['augementation_salaire_precedente'].str.rstrip('%').astype(float) / 100

# %%
df_merge['augementation_salaire_precedente'].value_counts()
# Out:
# augementation_salaire_precedente
# 0.11    210
# 0.13    209
# 0.14    201
# 0.12    198
# 0.15    101
# 0.18     89
# 0.17     82
# 0.16     78
# 0.19     76
# 0.22     56
# 0.20     55
# 0.21     48
# 0.23     28
# 0.24     21
# 0.25     18
# Name: count, dtype: int64

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   id_employee                                1470 non-null   int64
#  1   age                                        1470 non-null   int64
#  2   genre                                      1470 non-null   int64
#  3   revenu_mensuel                             1470 non-null   int64
#  4   statut_marital                             1470 non-null   object
#  5   departement                                1470 non-null   object
#  6   poste                                      1470 non-null   object
#  7   nombre_experiences_precedentes             1470 non-null   int64
#  8   annee_experience_totale                    1470 non-null   int64
#  9   annees_dans_l_entreprise                   1470 non-null   int64
#  10  annees_dans_le_poste_actuel                1470 non-null   int64
#  11  satisfaction_employee_environnement        1470 non-null   int64
#  12  note_evaluation_precedente                 1470 non-null   int64
#  13  niveau_hierarchique_poste                  1470 non-null   int64
#  14  satisfaction_employee_nature_travail       1470 non-null   int64
#  15  satisfaction_employee_equipe               1470 non-null   int64
#  16  satisfaction_employee_equilibre_pro_perso  1470 non-null   int64
#  17  note_evaluation_actuelle                   1470 non-null   int64
#  18  heure_supplementaires                      1470 non-null   int64
#  19  augementation_salaire_precedente           1470 non-null   float64
#  20  a_quitte_l_entreprise                      1470 non-null   int64
#  21  nombre_participation_pee                   1470 non-null   int64
#  22  nb_formations_suivies                      1470 non-null   int64
#  23  nombre_employee_sous_responsabilite        1470 non-null   int64
#  24  distance_domicile_travail                  1470 non-null   int64
#  25  niveau_education                           1470 non-null   int64
#  26  domaine_etude                              1470 non-null   object
#  27  ayant_enfants                              1470 non-null   int64
#  28  frequence_deplacement                      1470 non-null   object
#  29  annees_depuis_la_derniere_promotion        1470 non-null   int64
#  30  annes_sous_responsable_actuel              1470 non-null   int64
# dtypes: float64(1), int64(25), object(5)
# memory usage: 367.5+ KB

# %%
#colonne a encodé frequence_deplacement, domaine_etude, poste, departement, statut_marital
def encode_column_with_onehot(df, column_name, max_categories=100):
    # Initialiser le OneHotEncoder
    if column_name not in df.columns:
        print(f"La colonne '{column_name}' n'existe pas dans le DataFrame.")
        return df  # Retourner le DataFrame original sans modification
    encoder = OneHotEncoder(sparse_output=False, drop='first', max_categories=max_categories)  # drop='first' pour éviter la multicolinéarité
    # Appliquer l'encodage sur la colonne spécifiée
    encoded_array = encoder.fit_transform(df[[column_name]])
    # Récupérer les noms des colonnes encodées
    encoded_cols = encoder.get_feature_names_out([column_name])
    # Créer un DataFrame avec les colonnes encodées
    df_encoded = pd.DataFrame(encoded_array, columns=encoded_cols, index=df.index) # faire en sorte que les colonne soit encodé en object ou int 
    # Supprimer la colonne originale
    df = df.drop(columns=[column_name])
    # Concaténer le DataFrame original avec les colonnes encodées
    df_final = pd.concat([df, df_encoded], axis=1)
    return df_final

# %%
df_merge.to_csv("processed/data_merge_p2.csv")

#df = encode_column_with_onehot(df_merge, "frequence_deplacement")
#df = encode_column_with_onehot(df, "domaine_etude")
#df = encode_column_with_onehot(df, "poste")
#df = encode_column_with_onehot(df, "departement")
#df = encode_column_with_onehot(df, "statut_marital")
